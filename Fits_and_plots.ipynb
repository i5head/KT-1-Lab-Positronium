# %%
print("Hello World")
# Out:
# Hello World

# %%
import numpy as np
import matplotlib.pyplot as plt

def read_spe_integers(filename):
    """
    Reads a text-based .Spe file and returns the numeric contents as a list of integers.
    Ignores empty lines or lines that cannot be converted to integers.
    """
    int_values = []
    with open(filename, 'r', encoding='utf-8', errors='ignore') as file:
        for line in file:
            line = line.strip()  # remove whitespace and newline
            if line:  # skip blank lines
                try:
                    value = int(line)
                    int_values.append(value)
                except ValueError:
                    # Skip lines that aren't integers
                    continue
    return int_values

def cleanup_spe_file(input_data):
    # cleans up the data if necessary, currently does nothing, as all entries are useful
    cleaned_data = input_data[:]
    cleaned_array = np.array(cleaned_data)
    return cleaned_array

filepath = "Monday_Energy_left_1275_gate.Spe"

raw_data_lines = read_spe_integers(filepath)
clean_data = cleanup_spe_file(raw_data_lines)

# Create histogram
plt.plot(clean_data)

plt.title("Energy left 1275")
plt.xlabel("Bin number")
plt.ylabel("Number of events")

plt.ylim(0,15)

plt.show()

plt.close()

#

filepath = "Monday_Energy_left_nogate.Spe"

raw_data_lines = read_spe_integers(filepath)
clean_data = cleanup_spe_file(raw_data_lines)

# Create histogram
plt.plot(clean_data)

plt.title("Energy left nogate")
plt.xlabel("Bin number")
plt.ylabel("Number of events")

plt.ylim(0,50)

plt.show()

plt.close()

#

filepath = "Monday_Energy_right_511_gate.Spe"

raw_data_lines = read_spe_integers(filepath)
clean_data = cleanup_spe_file(raw_data_lines)

# Create histogram
plt.plot(clean_data)

plt.title("Energy right 511")
plt.xlabel("Bin number")
plt.ylabel("Number of events")

plt.ylim(0,100)

plt.show()

plt.close()

#

filepath = "Monday_Energy_right_nogate.Spe"

raw_data_lines = read_spe_integers(filepath)
clean_data = cleanup_spe_file(raw_data_lines)

# Create histogram
plt.plot(clean_data)

plt.title("Energy right nogate")
plt.xlabel("Bin number")
plt.ylabel("Number of events")

plt.ylim(0,50)

plt.show()

plt.close()

#

filepath = "Monday_time_511_511_gate.Spe"

raw_data_lines = read_spe_integers(filepath)
clean_data = cleanup_spe_file(raw_data_lines)

# Create histogram
plt.plot(clean_data)

plt.title("Time 511 511")
plt.xlabel("Bin number")
plt.ylabel("Number of events")

plt.ylim(0,15)

plt.show()

plt.close()
